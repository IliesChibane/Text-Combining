# %%
import pandas as pd
import numpy as np
import random
import urllib.request
import nltk
nltk.download('words', quiet=True)
nltk.download('names', quiet=True)

# Load the CMU Pronouncing Dictionary from the internet
url = "http://svn.code.sf.net/p/cmusphinx/code/trunk/cmudict/cmudict-0.7b"
with urllib.request.urlopen(url) as f:
    cmudict = f.read().decode("ISO-8859-1")

# %%
import pyphen

def split_into_morphemes(word):
    # Initialize the Pyphen dictionary
    dic = pyphen.Pyphen(lang='en')
    
    # Split the word into morphemes
    morphemes = dic.inserted(word).split('-')
    
    return morphemes

# Example usage:
word = "telepathy"
morphemes = split_into_morphemes(word)
print(morphemes)
# Out:
# ['tele', 'pathy']

# %%
import pyphonetics
import pronouncing


# Define a function that generates homophones for a given word
def generate_homophones(word):
    homophones = []
    # Create an instance of the Soundex algorithm
    soundex = pyphonetics.RefinedSoundex() #There are many others but this is the best one
    # Convert the input word to its Soundex code
    try:
        soundex_code = soundex.phonetics(word)

    # Compare the Soundex code of the input word with the Soundex code of each word in the CMU Pronouncing Dictionary
        for line in cmudict.splitlines():
            if line.startswith(";;;"):
                continue
            line = line.strip().split()
            pron = "".join(line[1:])
            pron_code = soundex.phonetics(pron)
            if soundex_code == pron_code:
                homophones.append(line[0])

        # Return the list of homophones
        homophones.extend(pronouncing.rhymes(word))
    except IndexError:
        return pronouncing.rhymes(word)
    return list(set(homophones))

# %%
import re

def clean_words(words): # Some word have special characters

    clean_words = []
    for word in words:
        clean_word = re.sub(r'[^a-zA-Z]', '', word)
        if clean_word and is_english_word_or_name(word):
            clean_words.append(clean_word)
    return [w.upper() for w in clean_words]

# %%
def put_word(sentence, word, potential_replacement):
    if potential_replacement is None or word is None:
        return sentence
    else:
        return sentence.replace(" " + word + " ", " " + potential_replacement + " ")

# %%
import random

def replace_word(word, word_list): #if there are no homophones i use this to return the word as it it, else i'll select a random homophone
    if not word_list:
        return word
    else:
        return random.choice(sorted(word_list))

# %%
def generate_morpheme_from_sentence(sentence):
    wordlist= []
    for word in sentence.split():
        wordlist.append(split_into_morphemes(word))
        
    return wordlist

# %%
def is_english_word_or_name(word): #APIS sometimes return with names and soetimes return just false words

    # Download the English names corpus if necessary
    nltk.download('names', quiet=True)
    
    # Get a set of English words and names
    english_words = set(nltk.corpus.words.words())
    english_names = set(nltk.corpus.names.words())
    
    # Check if the word is in the set of English words or names
    if word.lower() in english_words or word.title() in english_names:
        return True
    else:
        return False

# %%
def flatten_list_of_lists(list_of_lists):
    result = []
    for inner_list in list_of_lists:
        result.extend(inner_list)
    return result

# %%
def generate_ngram_dataset(path):
    data = pd.read_excel(path)
    data = data[['Target','sentence 1', 'sentence 2']]
    data['sentence 3'] = np.nan
    
    
    for index in range(len(data)+1):
        if index<805:continue
        columns = list(data.columns)
        columns.remove('sentence 3')
        columns.remove('Target')
        while columns:
            column = random.choice(columns)
            senten = data[column][index]
            data.loc[index, 'sentence 3'] = senten
            new_sentence_morph3D = generate_morpheme_from_sentence(senten)
            new_new_sentence_morph = flatten_list_of_lists(new_sentence_morph3D)

            if len(senten.split())==len(new_new_sentence_morph):
                columns.remove(column)
# Finished with iteration : 1164
# Finished with iteration : 1165
# Finished with iteration : 1166
# Finished with iteration : 1167
# Finished with iteration : 1168
# Finished with iteration : 1169
# Finished with iteration : 1170
# Finished with iteration : 1171
# Finished with iteration : 1172
# Finished with iteration : 1173
# Finished with iteration : 1174
# Finished with iteration : 1175
# Finished with iteration : 1176
# Finished with iteration : 1177
# Finished with iteration : 1178
# Finished with iteration : 1179
# Finished with iteration : 1180
# Finished with iteration : 1181
# Finished with iteration : 1182
# Finished with iteration : 1183
# Finished with iteration : 1184
# Finished with iteration : 1185
# Finished with iteration : 1186
# Finished with iteration : 1187
# Finished with iteration : 1188
# Finished with iteration : 1189
# Finished with iteration : 1190
# Finished with iteration : 1191
# Finished with iteration : 1192
# Finished with iteration : 1193
# Finished with iteration : 1194
# Finished with iteration : 1195
# Finished with iteration : 1196
# Finished with iteration : 1197
# Finished with iteration : 1198
# Finished with iteration : 1199
# Finished with iteration : 1200
# Finished with iteration : 1201
# Finished with iteration : 1202
# Finished with iteration : 1203
# Finished with iteration : 1204
# Finished with iteration : 1205
# Finished with iteration : 1206
# Finished with iteration : 1207
# Finished with iteration : 1208
# Finished with iteration : 1209
# Finished with iteration : 1210
# Finished with iteration : 1211
# Finished with iteration : 1212
# Finished with iteration : 1213
# Finished with iteration : 1214
# Finished with iteration : 1215
# Finished with iteration : 1216
# Finished with iteration : 1217
# Finished with iteration : 1218
# Finished with iteration : 1219
# Finished with iteration : 1220
# Finished with iteration : 1221
# Finished with iteration : 1222
# Finished with iteration : 1223
# Finished with iteration : 1224
# Finished with iteration : 1225
# Finished with iteration : 1226
# Finished with iteration : 1227
# Finished with iteration : 1228
# Finished with iteration : 1229
# Finished with iteration : 1230
# Finished with iteration : 1231
# Finished with iteration : 1232
# Finished with iteration : 1233
# Finished with iteration : 1234
# Finished with iteration : 1235
# Finished with iteration : 1236
# Finished with iteration : 1237
# Finished with iteration : 1238
# Finished with iteration : 1239
# Finished with iteration : 1240
# Finished with iteration : 1241
# Finished with iteration : 1242
# Finished with iteration : 1243
# Finished with iteration : 1244
# Finished with iteration : 1245
# Finished with iteration : 1246
# Finished with iteration : 1247
# Finished with iteration : 1248
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dff = generate_ngram_dataset('final-dataset-3005.xlsx')
#       2 dff.head()
#
# Cell In[10], line 25, in generate_ngram_dataset(path)
#      23 for w in new_new_sentence_morph:
#      24     if w.islower():
# ---> 25         potential_replacement = replace_word(w,list(set(clean_words(generate_homophones(w)))))
#      26         morphed = put_word(morphed, w, potential_replacement)
#      27     else:continue
#
# Cell In[4], line 8, in clean_words(words)
#       6 for word in words:
#       7     clean_word = re.sub(r'[^a-zA-Z]', '', word)
# ----> 8     if clean_word and is_english_word_or_name(word):
#       9         clean_words.append(clean_word)
#      10 return [w.upper() for w in clean_words]
#
# Cell In[8], line 8, in is_english_word_or_name(word)
#       6 # Get a set of English words and names
#       7 english_words = set(nltk.corpus.words.words())
# ----> 8 english_names = set(nltk.corpus.names.words())
#      10 # Check if the word is in the set of English words or names
#      11 if word.lower() in english_words or word.title() in english_names:
#
# KeyboardInterrupt:
